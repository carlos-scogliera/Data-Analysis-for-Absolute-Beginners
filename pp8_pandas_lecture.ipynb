# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-scogliera/Data-Analysis-for-Absolute-Beginners/blob/master/pp8_pandas_lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# calling in a dataframe using nested lists

data_vals = [[1, 2, 3], [4, 5, 6]]
data_cols = ['a', 'b', 'c']
df = pd.DataFrame(data=data_vals, columns=data_cols)
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
# calling in a data frame using dictionaries
data_lst = [{'a': 1, 'b': 2, 'c':3}, {'a': 4, 'b':5, 'c':6, 'd':7}]
df = pd.DataFrame(data_lst)
df
# Out:
#    a  b  c    d
# 0  1  2  3  NaN
# 1  4  5  6  7.0

# %%
# keys are the column names, if you don't have keys you will end up with nan values

data_lst = [{'a': 1, 'b':1.5}, {'b':'five'}, {'c': 4, 'b':66}]
df = pd.DataFrame(data_lst)
print(df)
# Out:
#      a     b    c
# 0  1.0   1.5  NaN
# 1  NaN  five  NaN
# 2  NaN    66  4.0

# %%
# note calling in data frames with nested lists doesn't exactly work like dictionaries do
data_vals = [[1, 2], [4, 5, 6]]
data_cols = ['a', 'b']
df = pd.DataFrame(data=data_vals, columns=data_cols)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     499         result = _convert_object_array(
# --> 500             content, columns, dtype=dtype, coerce_float=coerce_float
#     501         )
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     582                 "{col:d} columns passed, passed data had "
# --> 583                 "{con} columns".format(col=len(columns), con=len(content))
#     584             )
#
# AssertionError: 2 columns passed, passed data had 3 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-812580ea08c7> in <module>()
#       1 data_vals = [[1, 2], [4, 5, 6]]
#       2 data_cols = ['a', 'b']
# ----> 3 df = pd.DataFrame(data=data_vals, columns=data_cols)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     448                     if is_named_tuple(data[0]) and columns is None:
#     449                         columns = data[0]._fields
# --> 450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     451                     columns = ensure_index(columns)
#     452
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     462         return [], []  # columns if columns is not None else []
#     463     if isinstance(data[0], (list, tuple)):
# --> 464         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     465     elif isinstance(data[0], abc.Mapping):
#     466         return _list_of_dict_to_arrays(
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     501         )
#     502     except AssertionError as e:
# --> 503         raise ValueError(e) from e
#     504     return result
#     505
#
# ValueError: 2 columns passed, passed data had 3 columns

# %%
#this is how we would need to change the above code
data_vals = [[1, 2], [4, 5, 6]]
data_cols = ['a', 'b', 'c']
df = pd.DataFrame(data=data_vals, columns=data_cols)
df
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  4  5  6.0

# %% [markdown]
# # Let's read in external data:

# %%
#note because we are using colabs we are loading in data a little differen than you would on your computer
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['winequality-red.csv']))
# Out:
#      <input type="file" id="files-81b63ba9-a5ad-45bb-ac16-45b927447443" name="files[]" multiple disabled />
#      <output id="result-81b63ba9-a5ad-45bb-ac16-45b927447443">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red.csv

# %%
df = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
df.shape # Gives you the number of rows and number of columns
# Out:
# (1599, 12)

# %%
df.columns # Gives you back a list of all of the column names.
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info() # Allows you to look at the data type for each column, and the number of null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe() # Gives you summary statistics for all of your numeric columns.
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
df.head() # Shows you the first n columns (by default n = 5)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.tail() # Shows you the last n columns (by default n = 5).
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# 1598            6.0             0.310         0.47  ...       0.66     11.0        6
#
# [5 rows x 12 columns]

# %% [markdown]
# # Let's try grabbing columns and rows!

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df['chlorides'] # Grabs the 'chlorides' column.
# Out:
# 0       0.076
# 1       0.098
# 2       0.092
# 3       0.075
# 4       0.076
#         ...
# 1594    0.090
# 1595    0.062
# 1596    0.076
# 1597    0.075
# 1598    0.067
# Name: chlorides, Length: 1599, dtype: float64

# %%
df.chlorides # Alternate syntax ('dot notation') for grabbing the 'chlorides' column.
# Out:
# 0       0.076
# 1       0.098
# 2       0.092
# 3       0.075
# 4       0.076
#         ...
# 1594    0.090
# 1595    0.062
# 1596    0.076
# 1597    0.075
# 1598    0.067
# Name: chlorides, Length: 1599, dtype: float64

# %%
df['volatile acidity']
# df.volatile acidity # Dot notation only works if the column name has no spaces.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-22b1c1582528> in <module>()
# ----> 1 df['volatile acidity'].info()
#       2 # df.volatile acidity # Dot notation only works if the column name has no spaces.
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df2 = df.copy()
cols = df2.columns.tolist()
cols = [col.replace(' ', '_') for col in cols]
df2.columns = cols
df2.head()
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
# We can access all of multiple columns by passing in a list of column names. 
df[['chlorides', 'volatile acidity']]
# Out:
#       chlorides  volatile acidity
# 0         0.076             0.700
# 1         0.098             0.880
# 2         0.092             0.760
# 3         0.075             0.280
# 4         0.076             0.700
# ...         ...               ...
# 1594      0.090             0.600
# 1595      0.062             0.550
# 1596      0.076             0.510
# 1597      0.075             0.645
# 1598      0.067             0.310
#
# [1599 rows x 2 columns]

# %%
df[:3] # This will grab from the beginning up to but not including the row at index 3.
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
#
# [3 rows x 12 columns]

# %%
# This will grab up to but not including the row at index 1 (i.e. it'll grab the row  at index 0). 
df[:1]
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4               0.7          0.0  ...       0.56      9.4        5
#
# [1 rows x 12 columns]

# %%
# This will not work because it is not a slice, and pandas instead looks for a column named 0. 
# It doesn't find one, hence the KeyError (remember that dataframes are mostly built up from dictionaries)
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-78a33f69c558> in <module>()
# ----> 1 df[1]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
# This won't work because we are trying to access a subset of rows 
# **and** columns at the same time, so pandas treats the slice as a column name. 
df[:1, 'volatile acidity']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-0e28e979e32c> in <module>()
# ----> 1 df[:1, 'volatile acidity']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, 1, None), 'volatile acidity')' is an invalid key

# %% [markdown]
# # Let's use .loc() and .iloc()

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
# .loc[] is label based. All of these will work, because they are recognized as labels on the 
# rows (index labels) or columns (column name labels). 
df.loc[0, 'fixed acidity'] # 0 is one of the index labels, and 'fixed acidity' is a column label.
# Out:
# 7.4

# %%
# Ranges on our index labels still work (as long as they're numeric).
df.loc[0:10, 'fixed acidity']
# Out:
# 0      7.4
# 1      7.8
# 2      7.8
# 3     11.2
# 4      7.4
# 5      7.4
# 6      7.9
# 7      7.3
# 8      7.8
# 9      7.5
# 10     6.7
# Name: fixed acidity, dtype: float64

# %%
df.loc[10:15, ['chlorides', 'fixed acidity']]
# Out:
#     chlorides  fixed acidity
# 10      0.097            6.7
# 11      0.071            7.5
# 12      0.089            5.6
# 13      0.114            7.8
# 14      0.176            8.9
# 15      0.170            8.9

# %%
# These will all fail because they attempt to access the columns by position integers, 
# and loc only takes labels. 
df.loc[0, 0]
df.loc[0:10, 0]
df.loc[10:15, [0, 4]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-b4afe3128dd3> in <module>()
# ----> 1 df.loc[0, 0]
#       2 df.loc[0:10, 0]
#       3 df.loc[10:15, [0, 4]]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     959                     return section
#     960                 # This is an elided recursive call to iloc/loc/etc'
# --> 961                 return getattr(section, self.name)[new_key]
#     962
#     963         raise IndexingError("not applicable")
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1847
#    1848         # fall thru to straight lookup
# -> 1849         self._validate_key(key, axis)
#    1850         return self._get_label(key, axis=axis)
#    1851
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1723
#    1724         if not is_list_like_indexer(key):
# -> 1725             self._convert_scalar_indexer(key, axis)
#    1726
#    1727     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     272         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     273         # a scalar
# --> 274         return ax._convert_scalar_indexer(key, kind=self.name)
#     275
#     276     def _convert_slice_indexer(self, key, axis: int):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    3136             elif kind in ["loc"] and is_integer(key):
#    3137                 if not self.holds_integer():
# -> 3138                     return self._invalid_indexer("label", key)
#    3139
#    3140         return key
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3338             "cannot do {form} indexing on {klass} with these "
#    3339             "indexers [{key}] of {kind}".format(
# -> 3340                 form=form, klass=type(self), key=key, kind=type(key)
#    3341             )
#    3342         )
#
# TypeError: cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
# The above will all work with .iloc[], though, since it takes integers (and not labels)
# df.iloc[0, 0]
# df.iloc[0:10, 0]
df.iloc[10:15, [0, 4]]
# Out:
#     fixed acidity  chlorides
# 10            6.7      0.097
# 11            7.5      0.071
# 12            5.6      0.089
# 13            7.8      0.114
# 14            8.9      0.176

# %%
# Using labels, though, like we did with .loc[], will NOT work. These will all fail
df.iloc[0, 'fixed acidity']
df.iloc[0:10, 'fixed acidity'] 
df.iloc[10:15, ['chlorides', 'fixed acidity']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     234             try:
# --> 235                 self._validate_key(k, i)
#     236             except ValueError:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    2034                 "Can only index by location with "
# -> 2035                 "a [{types}]".format(types=self._valid_types)
#    2036             )
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-b28a1f21aebf> in <module>()
# ----> 1 df.iloc[0, 'fixed acidity']
#       2 df.iloc[0:10, 'fixed acidity']
#       3 df.iloc[10:15, ['chlorides', 'fixed acidity']]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2090     def _getitem_tuple(self, tup):
#    2091
# -> 2092         self._has_valid_tuple(tup)
#    2093         try:
#    2094             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     237                 raise ValueError(
#     238                     "Location based indexing can only have "
# --> 239                     "[{types}] types".format(types=self._valid_types)
#     240                 )
#     241
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %% [markdown]
# # Let's mask our dataframe

# %%
df['chlorides'] <= 0.08 # This just gives us a mask - tells us True or False whether each row 
                        # fit's the condition.
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1594    False
# 1595     True
# 1596     True
# 1597     True
# 1598     True
# Name: chlorides, Length: 1599, dtype: bool

# %%
# To use a mask, we actually have to use it to index into the DataFrame (using square brackets). 
df[df['chlorides'] <= 0.08]
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# 5               7.4             0.660         0.00  ...       0.56      9.4        5
# 6               7.9             0.600         0.06  ...       0.46      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1593            6.8             0.620         0.08  ...       0.82      9.5        6
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# 1598            6.0             0.310         0.47  ...       0.66     11.0        6
#
# [874 rows x 12 columns]

# %%
# Okay, this is cool. What if I wanted a slightly more complicated query...
df[(df['chlorides'] >= 0.04) & (df['chlorides'] < 0.08)]
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# 5               7.4             0.660         0.00  ...       0.56      9.4        5
# 6               7.9             0.600         0.06  ...       0.46      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1593            6.8             0.620         0.08  ...       0.82      9.5        6
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# 1598            6.0             0.310         0.47  ...       0.66     11.0        6
#
# [799 rows x 12 columns]

# %%
# So I could write an arbitrarily complicated query using that syntax... 
df[(df.chlorides >= 0.04) & (df['chlorides'] < 0.08) & (df['pH'] > 3.5) & (df['pH'] < 4.00)]
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# 5               7.4             0.660         0.00  ...       0.56      9.4        5
# 45              4.6             0.520         0.15  ...       0.56     13.1        4
# 94              5.0             1.020         0.04  ...       0.48     10.5        4
# ...             ...               ...          ...  ...        ...      ...      ...
# 1581            6.2             0.560         0.09  ...       0.60     11.3        5
# 1582            6.1             0.715         0.10  ...       0.50     11.9        5
# 1587            5.8             0.610         0.11  ...       0.66     10.9        6
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
#
# [108 rows x 12 columns]

# %%
# Or I could use the query() method that is available on our dataframe object. 
df.query('chlorides >= 0.04 and chlorides < 0.08 and pH > 3.5 and pH < 4.00')
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# 5               7.4             0.660         0.00  ...       0.56      9.4        5
# 45              4.6             0.520         0.15  ...       0.56     13.1        4
# 94              5.0             1.020         0.04  ...       0.48     10.5        4
# ...             ...               ...          ...  ...        ...      ...      ...
# 1581            6.2             0.560         0.09  ...       0.60     11.3        5
# 1582            6.1             0.715         0.10  ...       0.50     11.9        5
# 1587            5.8             0.610         0.11  ...       0.66     10.9        6
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
#
# [108 rows x 12 columns]
